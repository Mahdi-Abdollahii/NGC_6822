# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Abdollahii/NGC_6822/blob/main/X_Match/NGC6822_X_Match_Spitzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mahdi-Abdollahii/NGC_6822.git
# Out:
# Cloning into 'NGC_6822'...
# remote: Enumerating objects: 1261, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 1261 (delta 111), reused 60 (delta 60), pack-reused 1066
# Receiving objects: 100% (1261/1261), 103.44 MiB | 20.49 MiB/s, done.
# Resolving deltas: 100% (612/612), done.
# Updating files: 100% (138/138), done.

# %%
# !git clone https://github.com/Mahdi-Abdollahii/AstroDC.git
# Out:
# Cloning into 'AstroDC'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 319 (delta 73), reused 128 (delta 50), pack-reused 135
# Receiving objects: 100% (319/319), 6.86 MiB | 10.42 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
pip install git+https://github.com/Mahdi-Abdollahii/AstroDC.git
# Out:
# Collecting git+https://github.com/Mahdi-Abdollahii/AstroDC.git
#   Cloning https://github.com/Mahdi-Abdollahii/AstroDC.git to /tmp/pip-req-build-voju7jqv
#   Running command git clone --filter=blob:none --quiet https://github.com/Mahdi-Abdollahii/AstroDC.git /tmp/pip-req-build-voju7jqv
#   Resolved https://github.com/Mahdi-Abdollahii/AstroDC.git to commit 8316e67aa8d5f03931b6aa7743d9d8db596366f4
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: AstroDC
#   Building wheel for AstroDC (setup.py) ... done
#   Created wheel for AstroDC: filename=AstroDC-1.0.5-py3-none-any.whl size=2586 sha256=4e2cbf53ab0eed53a3e36dc77c941dddd818bfacf7d868afd04272cd9a94766a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2febv7u/wheels/82/b8/db/4179fef6fc03770dd498d786816b5f961dce1b9a70bd9499cd
# Successfully built AstroDC
# Installing collected packages: AstroDC
# Successfully installed AstroDC-1.0.5

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from AstroDC import AstroDC

# %% [markdown]
# # Data

# %% [markdown]
# Making Df for Spitzer

# %%
AstroDC.Vizier_XMLCSV_to_CSV("/content/NGC_6822/Data/NGC_6822_Spitzer.tsv", "Spitzer")
Spitzer = pd.read_csv ("/content/Spitzer.csv")
# Out:
# Spitzer.csv file of this data saved in local directory.

# %% [markdown]
# Final_data

# %%
Final_data = pd.read_csv("/content/NGC_6822/Data/final_data_v2.csv")
Final_data
# Out:
#      Id-main  Ra(J2000) deg  Dec(J2000) deg       J    eJ       H    eH  \
# 0    10870.0     296.178920      -14.822860  17.520  0.04   16.53  0.04
# 1    10784.0     296.215450      -14.834690  17.450  0.03   16.53  0.04
# 2    11004.0     296.273410      -14.808610  17.600  0.03   16.62  0.03
# 3    11029.0     296.283080      -14.804970  17.460  0.03   16.55  0.02
# 4    12050.0     296.254270      -14.817640  18.170  0.07   17.25  0.10
# ..       ...            ...             ...     ...   ...     ...   ...
# 371      NaN     295.976105      -14.796489  18.250   NaN  17.411   NaN
# 372      NaN     296.003693      -14.974893  18.392   NaN   17.56   NaN
# 373  10032.0     296.226960      -14.801910  14.480   NaN   13.66   NaN
# 374  10074.0     296.240050      -14.807960  14.740   NaN   13.94   NaN
# 375  40397.0     296.243010      -14.746520  14.100   NaN    13.3   NaN
#
#          Ks   eKs Types       DCG
# 0    16.190  0.05     S  0.055301
# 1    16.200  0.06     S  0.036084
# 2    16.270  0.05     S  0.043961
# 3    16.220  0.05     S  0.053182
# 4    16.700  0.05     S  0.029053
# ..      ...   ...   ...       ...
# 371  17.052   NaN     C  0.253948
# 372  17.210   NaN     C  0.284993
# 373  13.340   NaN     s  0.003049
# 374  13.660   NaN     s  0.011856
# 375  12.990   NaN     s  0.056664
#
# [376 rows x 11 columns]

# %% [markdown]
# # Making Reg file From Spitzer

# %%
AstroDC.Reg_file( Spitzer , '_RAJ2000(deg)', '_DEJ2000(deg)', Units = u.deg , File_name='Spitzer' , Color = "red" )
# Out:
# Spitzer.reg file of this data saved in local directory.

# %% [markdown]
# #X_Match

# %% [markdown]
# ##Final data with spitzer

# %%
Main_cat = Final_data
Scnd_cat = Spitzer

# %%
Main_cat
# Out:
#      Id-main  Ra(J2000) deg  Dec(J2000) deg       J    eJ       H    eH  \
# 0    10870.0     296.178920      -14.822860  17.520  0.04   16.53  0.04
# 1    10784.0     296.215450      -14.834690  17.450  0.03   16.53  0.04
# 2    11004.0     296.273410      -14.808610  17.600  0.03   16.62  0.03
# 3    11029.0     296.283080      -14.804970  17.460  0.03   16.55  0.02
# 4    12050.0     296.254270      -14.817640  18.170  0.07   17.25  0.10
# ..       ...            ...             ...     ...   ...     ...   ...
# 371      NaN     295.976105      -14.796489  18.250   NaN  17.411   NaN
# 372      NaN     296.003693      -14.974893  18.392   NaN   17.56   NaN
# 373  10032.0     296.226960      -14.801910  14.480   NaN   13.66   NaN
# 374  10074.0     296.240050      -14.807960  14.740   NaN   13.94   NaN
# 375  40397.0     296.243010      -14.746520  14.100   NaN    13.3   NaN
#
#          Ks   eKs Types       DCG
# 0    16.190  0.05     S  0.055301
# 1    16.200  0.06     S  0.036084
# 2    16.270  0.05     S  0.043961
# 3    16.220  0.05     S  0.053182
# 4    16.700  0.05     S  0.029053
# ..      ...   ...   ...       ...
# 371  17.052   NaN     C  0.253948
# 372  17.210   NaN     C  0.284993
# 373  13.340   NaN     s  0.003049
# 374  13.660   NaN     s  0.011856
# 375  12.990   NaN     s  0.056664
#
# [376 rows x 11 columns]

# %%
Scnd_cat
# Out:
#        _RAJ2000(deg)  _DEJ2000(deg)  RAJ2000(deg)  DEJ2000(deg)  IRAC1(mag)  \
# 0         296.024139      -14.67808    296.024139     -14.67808       18.68
# 1         296.025177      -14.68255    296.025177     -14.68255       19.07
# 2         296.026123      -14.68569    296.026123     -14.68569       18.15
# 3         296.026154      -14.68804    296.026154     -14.68804       19.30
# 4         296.026642      -14.67684    296.026642     -14.67684       18.31
# ...              ...            ...           ...           ...         ...
# 28819     296.449615      -14.90655    296.449615     -14.90655       18.42
# 28820     296.450195      -14.90560    296.450195     -14.90560       18.87
# 28821     296.450745      -14.90709    296.450745     -14.90709       17.05
# 28822     296.450775      -14.91540    296.450775     -14.91540       17.71
# 28823     296.451355      -14.91336    296.451355     -14.91336       18.89
#
#        dIRAC1(mag)  IRAC2(mag)  dIRAC2(mag) l_IRAC3( )  IRAC3(mag)  \
# 0             0.00       18.26         0.00                  16.40
# 1             0.42       18.43         0.00          >       16.38
# 2             0.32       17.79         0.24          >       16.32
# 3             0.00       19.03         0.00                  16.33
# 4             0.00       17.83        -0.05                  17.28
# ...            ...         ...          ...        ...         ...
# 28819        -0.46       17.80         0.22          >       16.55
# 28820        -0.07       18.03         0.00          >       16.50
# 28821        -0.21       16.71         0.00                  16.24
# 28822         0.63       16.65         0.00                  16.35
# 28823         0.75       17.47         0.00                  16.08
#
#        dIRAC3(mag) l_IRAC4( )  IRAC4(mag)  dIRAC4(mag) l_MIPS24( )  \
# 0             0.00          >       16.53          0.0
# 1             0.00          >       16.12          0.0           >
# 2             0.00          >       16.28          0.0           >
# 3             0.00          >       16.24          0.0           >
# 4             0.00          >       16.14          0.0           >
# ...            ...        ...         ...          ...         ...
# 28819         0.00          >       15.35          0.0           >
# 28820         0.00          >        0.00          0.0           >
# 28821        -0.59                  15.63          0.0           >
# 28822         0.00          >        0.00          0.0           >
# 28823         0.00          >       16.02          0.0           >
#
#        MIPS24(mag)
# 0            11.85
# 1            12.06
# 2            11.92
# 3            12.16
# 4            12.75
# ...            ...
# 28819        11.98
# 28820        11.79
# 28821        11.98
# 28822        12.05
# 28823        12.32
#
# [28824 rows x 16 columns]

# %%
Main_cat_Coord = SkyCoord(Main_cat['Ra(J2000) deg'], Main_cat['Dec(J2000) deg'], unit=(u.deg, u.deg))
Scnd_cat_Coord = SkyCoord(Scnd_cat['_RAJ2000(deg)'], Scnd_cat['_DEJ2000(deg)'], unit=(u.deg, u.deg))

# %%
idx, d2D, d3D = Scnd_cat_Coord.match_to_catalog_sky(Main_cat_Coord)

# %%
max_sep = 1.0 * u.arcsec        # Maximum erorr
i_OK = d2D < max_sep

# %%
Secondary_catalog = Scnd_cat[i_OK]
Main_catalog = Main_cat.iloc[idx[i_OK]]

# %% [markdown]
# Making CSV file

# %%
Secondary_catalog.to_csv(r'Secondary_catalog.csv', header=True, index=None, sep='\t', mode='w')
Main_catalog.to_csv(r'Main_catalog.csv', header=True, index=None, sep='\t', mode='w')

# %%
with open("Main_catalog.csv") as f1, open("Secondary_catalog.csv") as f2, open("X_Catalog.csv", "w") as f3:
     for x, y in zip(f1, f2):
          f3.write(x.strip() + '\t' + y.strip() + '\n')
f1.close()
f2.close()
f3.close()

# %%
X_data = pd.read_csv ("X_Catalog.csv", sep = '\t')
X_data
# Out:
#         Id-main  Ra(J2000) deg  Dec(J2000) deg   J     eJ   H      eH  Ks eKs  \
# 0    296.042917     -14.782194          17.033 NaN    NaN NaN  15.322 NaN   C
# 1    296.051208     -14.726806          17.588 NaN    NaN NaN  15.526 NaN   C
# 2    296.051292     -14.866694          17.677 NaN    NaN NaN  15.785 NaN   C
# 3    296.064208     -14.736028          17.690 NaN    NaN NaN  15.998 NaN   C
# 4    296.066071     -14.844581          17.440 NaN  16.78 NaN  16.300 NaN  C
# ..          ...            ...             ...  ..    ...  ..     ...  ..  ..
# 299  296.410208     -14.849806          17.290 NaN    NaN NaN  15.674 NaN   C
# 300  296.421167     -14.747139          17.534 NaN    NaN NaN  15.979 NaN   C
# 301  296.431213     -14.889406          17.330 NaN  16.48 NaN  16.180 NaN   C
# 302  296.434357     -14.834667          17.480 NaN  16.72 NaN  16.320 NaN   C
# 303  296.436125     -14.895139          17.603 NaN    NaN NaN  15.882 NaN   C
#
#                   Types  ...  IRAC2(mag)  dIRAC2(mag)  l_IRAC3( )  IRAC3(mag)  \
# 0     0.188094281083234  ...       -0.06                    14.85       -0.08
# 1    0.1938328051837856  ...        0.01                    15.09       -0.26
# 2    0.1901705400061158  ...       -0.02                    15.34        0.09
# 3     0.178313737091168  ...        0.03                     15.4       -0.25
# 4    0.1694522675032668  ...        0.20                    15.41       -0.09
# ..                  ...  ...         ...          ...         ...         ...
# 299  0.1865263078640786  ...       -0.05                    14.87       -0.36
# 300  0.1987922260721497  ...        0.01                    14.85       -0.28
# 301  0.2195091730771135  ...       -0.05                    15.44       -0.41
# 302   0.207003829573231  ...       -0.04                    15.47       -0.44
# 303  0.2263270841565948  ...       -0.15                    14.91       -0.38
#
#      dIRAC3(mag)  l_IRAC4( )  IRAC4(mag)  dIRAC4(mag) l_MIPS24( ) MIPS24(mag)
# 0                      14.33       -0.45            >       12.37         NaN
# 1                      14.64        0.00            >       12.31         NaN
# 2                      14.94        0.18                    11.63         NaN
# 3                      15.12       -0.17            >        12.3         NaN
# 4                      14.93       -0.85            >       11.85         NaN
# ..           ...         ...         ...          ...         ...         ...
# 299                    14.74       -0.08            >       13.27         NaN
# 300                    14.72       -0.05            >       12.41         NaN
# 301                    15.46        0.00            >       11.89         NaN
# 302                    15.63       -0.46            >       12.45         NaN
# 303                    14.43        0.06            >       12.33         NaN
#
# [304 rows x 27 columns]
