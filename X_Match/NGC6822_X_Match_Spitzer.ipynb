# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Abdollahii/NGC_6822/blob/main/X_Match/NGC6822_X_Match_Spitzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Mahdi-Abdollahii/NGC_6822.git
# Out:
# Cloning into 'NGC_6822'...
# remote: Enumerating objects: 1325, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 1325 (delta 145), reused 175 (delta 113), pack-reused 1066
# Receiving objects: 100% (1325/1325), 105.93 MiB | 14.68 MiB/s, done.
# Resolving deltas: 100% (646/646), done.
# Updating files: 100% (139/139), done.

# %%
# !git clone https://github.com/Mahdi-Abdollahii/AstroDC.git
# Out:
# Cloning into 'AstroDC'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 319 (delta 73), reused 128 (delta 50), pack-reused 135
# Receiving objects: 100% (319/319), 6.86 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
pip install git+https://github.com/Mahdi-Abdollahii/AstroDC.git
# Out:
# Collecting git+https://github.com/Mahdi-Abdollahii/AstroDC.git
#   Cloning https://github.com/Mahdi-Abdollahii/AstroDC.git to /tmp/pip-req-build-wrbthasb
#   Running command git clone --filter=blob:none --quiet https://github.com/Mahdi-Abdollahii/AstroDC.git /tmp/pip-req-build-wrbthasb
#   Resolved https://github.com/Mahdi-Abdollahii/AstroDC.git to commit 8316e67aa8d5f03931b6aa7743d9d8db596366f4
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: AstroDC
#   Building wheel for AstroDC (setup.py) ... done
#   Created wheel for AstroDC: filename=AstroDC-1.0.5-py3-none-any.whl size=2586 sha256=19f61b8f8e66dd2e659cdf6430c2d2c55cb341f4cb2ee44f128c2cb5c71154c2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cjniguqw/wheels/82/b8/db/4179fef6fc03770dd498d786816b5f961dce1b9a70bd9499cd
# Successfully built AstroDC
# Installing collected packages: AstroDC
# Successfully installed AstroDC-1.0.5

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from AstroDC import AstroDC

# %% [markdown]
# # Data

# %% [markdown]
# Making Df for Spitzer

# %%
AstroDC.Vizier_XMLCSV_to_CSV("/content/NGC_6822/Data/NGC_6822_Spitzer.tsv", "Spitzer")
Spitzer = pd.read_csv ("/content/Spitzer.csv")
# Out:
# Spitzer.csv file of this data saved in local directory.

# %% [markdown]
# Final_data

# %%
Final_data = pd.read_csv("/content/NGC_6822/Data/final_data_v2.csv")
Final_data
# Out:
#      Id-main  Ra(J2000) deg  Dec(J2000) deg       J    eJ       H    eH  \
# 0    10870.0     296.178920      -14.822860  17.520  0.04   16.53  0.04
# 1    10784.0     296.215450      -14.834690  17.450  0.03   16.53  0.04
# 2    11004.0     296.273410      -14.808610  17.600  0.03   16.62  0.03
# 3    11029.0     296.283080      -14.804970  17.460  0.03   16.55  0.02
# 4    12050.0     296.254270      -14.817640  18.170  0.07   17.25  0.10
# ..       ...            ...             ...     ...   ...     ...   ...
# 371      NaN     296.187256      -14.854028  18.166   NaN  17.224   NaN
# 372      NaN     296.227081      -14.876891  17.543   NaN  16.457   NaN
# 373      NaN     296.226807      -14.881382  17.365   NaN  16.369   NaN
# 374      NaN     295.976105      -14.796489  18.250   NaN  17.411   NaN
# 375      NaN     296.003693      -14.974893  18.392   NaN   17.56   NaN
#
#          Ks   eKs Types       DCG    Catalog
# 0    16.190  0.05     S  0.055301  Whitelock
# 1    16.200  0.06     S  0.036084  Whitelock
# 2    16.270  0.05     S  0.043961  Whitelock
# 3    16.220  0.05     S  0.053182  Whitelock
# 4    16.700  0.05     S  0.029053  Whitelock
# ..      ...   ...   ...       ...        ...
# 371  16.937   NaN     C  0.067590   Kacharov
# 372  15.858   NaN     C  0.075278   Kacharov
# 373  15.908   NaN     C  0.079776   Kacharov
# 374  17.052   NaN     C  0.253948   Kacharov
# 375  17.210   NaN     C  0.284993   Kacharov
#
# [376 rows x 12 columns]

# %% [markdown]
# # Making Reg file From Spitzer

# %%
AstroDC.Reg_file( Spitzer , '_RAJ2000(deg)', '_DEJ2000(deg)', Units = u.deg , File_name='Spitzer' , Color = "red" )
# Out:
# Spitzer.reg file of this data saved in local directory.

# %% [markdown]
# #X_Match

# %% [markdown]
# ##Final data with spitzer

# %%
Main_cat = Final_data
Scnd_cat = Spitzer

# %%
Main_cat
# Out:
#      Id-main  Ra(J2000) deg  Dec(J2000) deg       J    eJ       H    eH  \
# 0    10870.0     296.178920      -14.822860  17.520  0.04   16.53  0.04
# 1    10784.0     296.215450      -14.834690  17.450  0.03   16.53  0.04
# 2    11004.0     296.273410      -14.808610  17.600  0.03   16.62  0.03
# 3    11029.0     296.283080      -14.804970  17.460  0.03   16.55  0.02
# 4    12050.0     296.254270      -14.817640  18.170  0.07   17.25  0.10
# ..       ...            ...             ...     ...   ...     ...   ...
# 371      NaN     296.187256      -14.854028  18.166   NaN  17.224   NaN
# 372      NaN     296.227081      -14.876891  17.543   NaN  16.457   NaN
# 373      NaN     296.226807      -14.881382  17.365   NaN  16.369   NaN
# 374      NaN     295.976105      -14.796489  18.250   NaN  17.411   NaN
# 375      NaN     296.003693      -14.974893  18.392   NaN   17.56   NaN
#
#          Ks   eKs Types       DCG    Catalog
# 0    16.190  0.05     S  0.055301  Whitelock
# 1    16.200  0.06     S  0.036084  Whitelock
# 2    16.270  0.05     S  0.043961  Whitelock
# 3    16.220  0.05     S  0.053182  Whitelock
# 4    16.700  0.05     S  0.029053  Whitelock
# ..      ...   ...   ...       ...        ...
# 371  16.937   NaN     C  0.067590   Kacharov
# 372  15.858   NaN     C  0.075278   Kacharov
# 373  15.908   NaN     C  0.079776   Kacharov
# 374  17.052   NaN     C  0.253948   Kacharov
# 375  17.210   NaN     C  0.284993   Kacharov
#
# [376 rows x 12 columns]

# %%
Scnd_cat
# Out:
#        _RAJ2000(deg)  _DEJ2000(deg)  RAJ2000(deg)  DEJ2000(deg)  IRAC1(mag)  \
# 0         296.024139      -14.67808    296.024139     -14.67808       18.68
# 1         296.025177      -14.68255    296.025177     -14.68255       19.07
# 2         296.026123      -14.68569    296.026123     -14.68569       18.15
# 3         296.026154      -14.68804    296.026154     -14.68804       19.30
# 4         296.026642      -14.67684    296.026642     -14.67684       18.31
# ...              ...            ...           ...           ...         ...
# 28819     296.449615      -14.90655    296.449615     -14.90655       18.42
# 28820     296.450195      -14.90560    296.450195     -14.90560       18.87
# 28821     296.450745      -14.90709    296.450745     -14.90709       17.05
# 28822     296.450775      -14.91540    296.450775     -14.91540       17.71
# 28823     296.451355      -14.91336    296.451355     -14.91336       18.89
#
#        dIRAC1(mag)  IRAC2(mag)  dIRAC2(mag) l_IRAC3( )  IRAC3(mag)  \
# 0             0.00       18.26         0.00                  16.40
# 1             0.42       18.43         0.00          >       16.38
# 2             0.32       17.79         0.24          >       16.32
# 3             0.00       19.03         0.00                  16.33
# 4             0.00       17.83        -0.05                  17.28
# ...            ...         ...          ...        ...         ...
# 28819        -0.46       17.80         0.22          >       16.55
# 28820        -0.07       18.03         0.00          >       16.50
# 28821        -0.21       16.71         0.00                  16.24
# 28822         0.63       16.65         0.00                  16.35
# 28823         0.75       17.47         0.00                  16.08
#
#        dIRAC3(mag) l_IRAC4( )  IRAC4(mag)  dIRAC4(mag) l_MIPS24( )  \
# 0             0.00          >       16.53          0.0
# 1             0.00          >       16.12          0.0           >
# 2             0.00          >       16.28          0.0           >
# 3             0.00          >       16.24          0.0           >
# 4             0.00          >       16.14          0.0           >
# ...            ...        ...         ...          ...         ...
# 28819         0.00          >       15.35          0.0           >
# 28820         0.00          >        0.00          0.0           >
# 28821        -0.59                  15.63          0.0           >
# 28822         0.00          >        0.00          0.0           >
# 28823         0.00          >       16.02          0.0           >
#
#        MIPS24(mag)
# 0            11.85
# 1            12.06
# 2            11.92
# 3            12.16
# 4            12.75
# ...            ...
# 28819        11.98
# 28820        11.79
# 28821        11.98
# 28822        12.05
# 28823        12.32
#
# [28824 rows x 16 columns]

# %%
Main_cat_Coord = SkyCoord(Main_cat['Ra(J2000) deg'], Main_cat['Dec(J2000) deg'], unit=(u.deg, u.deg))
Scnd_cat_Coord = SkyCoord(Scnd_cat['_RAJ2000(deg)'], Scnd_cat['_DEJ2000(deg)'], unit=(u.deg, u.deg))

# %%
idx, d2D, d3D = Scnd_cat_Coord.match_to_catalog_sky(Main_cat_Coord)

# %%
max_sep = 1.0 * u.arcsec        # Maximum erorr
i_OK = d2D < max_sep

# %%
Secondary_catalog = Scnd_cat[i_OK]
Main_catalog = Main_cat.iloc[idx[i_OK]]

# %%
Main_catalog = Main_catalog.reset_index()
Secondary_catalog = Secondary_catalog.reset_index()

X_data = pd.concat([Main_catalog, Secondary_catalog], axis=1)

# %%
X_data
# Out:
#      index  Id-main  Ra(J2000) deg  Dec(J2000) deg       J  eJ      H  eH  \
# 0      210      NaN     296.042917      -14.782194  17.033 NaN    NaN NaN
# 1      212      NaN     296.051208      -14.726806  17.588 NaN    NaN NaN
# 2      213      NaN     296.051292      -14.866694  17.677 NaN    NaN NaN
# 3      215      NaN     296.064208      -14.736028  17.690 NaN    NaN NaN
# 4      192      NaN     296.066071      -14.844581  17.440 NaN  16.78 NaN
# ..     ...      ...            ...             ...     ...  ..    ...  ..
# 299    247      NaN     296.410208      -14.849806  17.290 NaN    NaN NaN
# 300    248      NaN     296.421167      -14.747139  17.534 NaN    NaN NaN
# 301    140      NaN     296.431213      -14.889406  17.330 NaN  16.48 NaN
# 302    132      NaN     296.434357      -14.834667  17.480 NaN  16.72 NaN
# 303    251      NaN     296.436125      -14.895139  17.603 NaN    NaN NaN
#
#          Ks  eKs  ... IRAC2(mag)  dIRAC2(mag) l_IRAC3( )  IRAC3(mag)  \
# 0    15.322  NaN  ...      14.95        -0.06                  14.85
# 1    15.526  NaN  ...      15.03         0.01                  15.09
# 2    15.785  NaN  ...      15.77        -0.02                  15.34
# 3    15.998  NaN  ...      15.71         0.03                  15.40
# 4    16.300  NaN  ...      15.98         0.20                  15.41
# ..      ...  ...  ...        ...          ...        ...         ...
# 299  15.674  NaN  ...      14.97        -0.05                  14.87
# 300  15.979  NaN  ...      15.53         0.01                  14.85
# 301  16.180  NaN  ...      15.79        -0.05                  15.44
# 302  16.320  NaN  ...      16.12        -0.04                  15.47
# 303  15.882  NaN  ...      15.13        -0.15                  14.91
#
#      dIRAC3(mag)  l_IRAC4( )  IRAC4(mag)  dIRAC4(mag)  l_MIPS24( )  \
# 0          -0.08                   14.33        -0.45            >
# 1          -0.26                   14.64         0.00            >
# 2           0.09                   14.94         0.18
# 3          -0.25                   15.12        -0.17            >
# 4          -0.09                   14.93        -0.85            >
# ..           ...         ...         ...          ...          ...
# 299        -0.36                   14.74        -0.08            >
# 300        -0.28                   14.72        -0.05            >
# 301        -0.41                   15.46         0.00            >
# 302        -0.44                   15.63        -0.46            >
# 303        -0.38                   14.43         0.06            >
#
#      MIPS24(mag)
# 0          12.37
# 1          12.31
# 2          11.63
# 3          12.30
# 4          11.85
# ..           ...
# 299        13.27
# 300        12.41
# 301        11.89
# 302        12.45
# 303        12.33
#
# [304 rows x 30 columns]

# %%
plt.hist(X_data['Catalog'])
# Out:
# (array([38.,  0.,  0., 82.,  0.,  0., 96.,  0.,  0., 88.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
X_data.to_csv("X_Match_Spitzer.csv")
